# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
# !gdown 1Q-ev_KbSlyw2kfLL6I9Mu8I4Sgb4RGM7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Q-ev_KbSlyw2kfLL6I9Mu8I4Sgb4RGM7
# To: /content/possum.csv
# 100% 5.48k/5.48k [00:00<00:00, 14.1MB/s]

# %%
df=pd.read_csv("possum.csv")

# %%
df
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [104 rows x 14 columns]

# %%
df.drop(columns=['case', 'site', 'Pop', 'sex'], inplace=True)

# %%
df
# Out:
#      age  hdlngth  skullw  totlngth  taill  footlgth  earconch   eye  chest  \
# 0    8.0     94.1    60.4      89.0   36.0      74.5      54.5  15.2   28.0
# 1    6.0     92.5    57.6      91.5   36.5      72.5      51.2  16.0   28.5
# 2    6.0     94.0    60.0      95.5   39.0      75.4      51.9  15.5   30.0
# 3    6.0     93.2    57.1      92.0   38.0      76.1      52.2  15.2   28.0
# 4    2.0     91.5    56.3      85.5   36.0      71.0      53.2  15.1   28.5
# ..   ...      ...     ...       ...    ...       ...       ...   ...    ...
# 99   1.0     89.5    56.0      81.5   36.5      66.0      46.8  14.8   23.0
# 100  1.0     88.6    54.7      82.5   39.0      64.4      48.0  14.0   25.0
# 101  6.0     92.4    55.0      89.0   38.0      63.5      45.4  13.0   25.0
# 102  4.0     91.5    55.2      82.5   36.5      62.9      45.9  15.4   25.0
# 103  3.0     93.6    59.9      89.0   40.0      67.6      46.0  14.8   28.5
#
#      belly
# 0     36.0
# 1     33.0
# 2     34.0
# 3     34.0
# 4     33.0
# ..     ...
# 99    27.0
# 100   33.0
# 101   30.0
# 102   29.0
# 103   33.5
#
# [104 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# age         2
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    1
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)
#
# Картинка взята [отсюда](https://towardsdatascience.com/knn-visualization-in-just-13-lines-of-code-32820d72c6b6).

# %%
a=[2.,2.]
b=[4.,4.]

# %%
from math import sqrt

# %%
def euclidean_dist(vec1,vec2):
  distance=0.0
  for i in range(len(vec1)):
    distance += (vec1[i]-vec2[i])**2
  return sqrt(distance)

# %%
euclidean_dist(a,b)
# Out:
# 2.8284271247461903

# %%
import numpy as np
def euclidean_dist_num(vec1,vec2):
  return np.linalg.norm(vec1-vec2)

# %%
euclidean_dist_num(np.array(a),np.array(b))
# Out:
# np.float64(2.8284271247461903)

# %%
df.dropna(inplace=True)
x=df.drop(['age'], axis=1)
y=df['age']

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, shuffle=True, test_size=0.2, random_state=44)

# %%
def get_neighbors(train, test_row, num_neighbors):
	distances = list()
	for train_id, train_row in enumerate(train):
		dist = euclidean_dist(test_row, train_row)
		distances.append((train_id, dist))

	distances.sort(key=lambda tup: tup[1])

	nearest_neighbor_ids = list()
	for i in range(num_neighbors):
		nearest_neighbor_ids.append(distances[i][0])
	return nearest_neighbor_ids
get_neighbors(X_train[:5], X_test[1], 3)

# %%
def predict(X_train, X_test, y_train, num_neighbors = 3):

    y_predict = []
    for X_test in X_test:
      neighbors_ids = get_neighbors(X_train, X_test, num_neighbors)
      nearest_neighbor_y = [y_train[id] for id in neighbors_ids]

      pred = np.mean(nearest_neighbor_y)
      y_predict.append(pred)

    return y_predict

# %%
y_predict=predict(X_train[:30], X_test[:5], y_train[:30], num_neighbors = 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_471/2929473915.py in <cell line: 0>()
# ----> 1 y_predict=predict(X_train[:30], X_test[:5], y_train[:30], num_neighbors = 5)
#
# /tmp/ipykernel_471/881495662.py in predict(X_train, X_test, y_train, num_neighbors)
#       3     y_predict = []
#       4     for X_test in X_test:
# ----> 5       neighbors_ids = get_neighbors(X_train, X_test, num_neighbors)
#       6       nearest_neighbor_y = [y_train[id] for id in neighbors_ids] # результаты
#       7
#
# /tmp/ipykernel_471/855717635.py in get_neighbors(train, test_row, num_neighbors)
#       2         distances = list()
#       3         for train_id, train_row in enumerate(train):
# ----> 4                 dist = euclidean_dist(test_row, train_row)
#       5                 distances.append((train_id, dist))
#       6
#
# /tmp/ipykernel_471/2518658626.py in euclidean_dist(vec1, vec2)
#       2   distance=0.0
#       3   for i in range(len(vec1)):
# ----> 4     distance += (vec1[i]-vec2[i])**2
#       5   return sqrt(distance)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
